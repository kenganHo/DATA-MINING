# %% [markdown]
# <a href="https://colab.research.google.com/github/kenganHo/DATA-MINING/blob/main/Colab_%EC%8B%9C%EC%9E%91%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch2/members.csv")

std = df['age'].std()
mean = df['age'].mean()

lower = mean - (std * 1.5)
upper = mean + (std * 1.5)

cond1 = df['age'] < lower
cond2 = df['age'] > upper

print(df[cond1|cond2]['age'].sum())
# Out:
# 473.5
